# %%
def outer(msg):
		message = msg
		print("this is outer function message is :", message)
		def inner(msg2):
				print(f"message from outer function: {message} message from inner function: {msg2}")

		return inner

# %%
func = outer("hi")
# Out:
# this is outer function message is : hi

# %%
func("hello")
# Out:
# message from outer function: hi message from inner function: hello
