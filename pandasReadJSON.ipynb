# %%
import pandas as pd

url = "https://official-joke-api.appspot.com/random_ten"
df = pd.read_json(url)
df
# Out:
#           type                                              setup  \
# 0      general                What's a computer's favorite snack?
# 1      general                        What kind of bagel can fly?
# 2  programming             Why did the programmer quit their job?
# 3      general                 Why are football stadiums so cool?
# 4      general  Where was the Declaration of Independence signed?
# 5      general               What kind of tree fits in your hand?
# 6      general        What kind of award did the dentist receive?
# 7      general              What do you call a cow with two legs?
# 8      general      What is a witch's favorite subject in school?
# 9      general               Why did the cookie go to the doctor?
#
#                              punchline   id
# 0                          Microchips.  423
# 1                       A plain bagel.  251
# 2              They didn't get arrays.  437
# 3  Because every seat has a fan in it.  404
# ...

# %%
df.to_csv("jokes.csv")
dfp = pd.read_csv("jokes.csv")
dfp
# Out:
#    Unnamed: 0         type                                              setup  \
# 0           0      general                What's a computer's favorite snack?
# 1           1      general                        What kind of bagel can fly?
# 2           2  programming             Why did the programmer quit their job?
# 3           3      general                 Why are football stadiums so cool?
# 4           4      general  Where was the Declaration of Independence signed?
# 5           5      general               What kind of tree fits in your hand?
# 6           6      general        What kind of award did the dentist receive?
# 7           7      general              What do you call a cow with two legs?
# 8           8      general      What is a witch's favorite subject in school?
# 9           9      general               Why did the cookie go to the doctor?
#
#                              punchline   id
# 0                          Microchips.  423
# ...

# %%
df.to_pickle("jokes.pkl")

# %%
dfp = pd.read_pickle("jokes.pkl") 
dfp
# Out:
#           type                                              setup  \
# 0      general                What's a computer's favorite snack?
# 1      general                        What kind of bagel can fly?
# 2  programming             Why did the programmer quit their job?
# 3      general                 Why are football stadiums so cool?
# 4      general  Where was the Declaration of Independence signed?
# 5      general               What kind of tree fits in your hand?
# 6      general        What kind of award did the dentist receive?
# 7      general              What do you call a cow with two legs?
# 8      general      What is a witch's favorite subject in school?
# 9      general               Why did the cookie go to the doctor?
#
#                              punchline   id
# 0                          Microchips.  423
# 1                       A plain bagel.  251
# 2              They didn't get arrays.  437
# 3  Because every seat has a fan in it.  404
# ...
