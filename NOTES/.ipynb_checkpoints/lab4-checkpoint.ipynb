# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("creditcard.csv")

print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (10, 23)
#    Time      V1      V2      V3      V4      V5      V6      V7      V8  \
# 0     0 -1.3598 -0.0727  2.5363  1.3781 -0.3383  0.4623  0.2396  0.0987
# 1     1  1.1918  0.2661  0.1665  0.4481  0.0600 -0.0823 -0.0788  0.0851
# 2     2 -1.3583 -1.3402  1.7732  0.3798 -0.5032  1.8004  0.7914  0.2477
# 3     3 -0.9662 -0.1852  1.7929 -0.8632 -0.0103  1.2472  0.2376  0.3774
# 4     4 -1.1582  0.8777  1.5487  0.4030 -0.4071  0.0959  0.5929 -0.2705
#
#        V9  ...     V13     V14     V15     V16     V17     V18     V19  \
# 0  0.3637  ... -0.9914 -0.3112  1.4682 -0.4704  0.2079  0.0257  0.4039
# 1 -0.2554  ...  0.4891 -0.1437  0.6356  0.4639 -0.1148 -0.1833 -0.1458
# 2 -1.5146  ...  0.7172 -0.1659  2.3458 -2.8901  1.1099 -0.1213 -2.2619
# 3 -1.3870  ...  0.5078 -0.2879 -0.6314 -1.0596 -0.6841  1.9658 -1.2326
# 4  0.8177  ...  1.3458 -1.1197  0.1751 -0.4514 -0.2370 -0.0382  0.8034
#
#       V20  Amount  Class
# 0  0.2514  149.62      0
# 1 -0.0691    2.69      0
# 2  0.5249  378.66      0
# 3 -0.2080  123.50      0
# 4  0.4085   69.99      0
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#            Time         V1         V2         V3         V4         V5  \
# count  10.00000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    4.50000  -0.643870   0.385530   0.486830   1.017820  -0.227050
# std     3.02765   1.508187   1.145010   1.795717   1.367467   0.462530
# min     0.00000  -3.043500  -1.340200  -3.459200  -0.863200  -1.117200
# 25%     2.25000  -1.359425  -0.169475   0.265950   0.385600  -0.479175
# 50%     4.50000  -1.062200   0.025350   0.777700   0.452400  -0.286400
# 75%     6.75000   0.827100   0.724800   1.717075   1.344900   0.042425
# max     9.00000   1.234500   2.591100   2.536300   3.997900   0.456700
#
#               V6         V7         V8         V9  ...        V13        V14  \
# count  10.000000  10.000000  10.000000  10.000000  ...  10.000000  10.000000
# mean   -0.045420  -0.211020   0.351020  -0.630130  ...   0.174470  -1.125570
# std     1.168503   1.157698   0.542404   1.280002  ...   0.715079   1.648810
# min    -2.205600  -2.537300  -0.270500  -2.770100  ...  -0.991400  -4.289300
# 25%    -0.401150  -0.128900   0.088500  -1.482700  ...  -0.387775  -0.926175
# 50%     0.006800   0.238600   0.234500  -0.189400  ...   0.345600  -0.328400
# 75%     0.433125   0.512250   0.344975   0.359175  ...   0.503125  -0.196400
# max     1.800400   0.791400   1.391700   0.817700  ...   1.345800  -0.123400
#
#              V15        V16        V17        V18       V19        V20  \
# count  10.000000  10.000000  10.000000  10.000000  10.00000  10.000000
# mean    0.598760  -0.607930  -0.637390   0.254530  -0.05226   0.186150
# std     0.800266   1.085841   1.243660   0.647188   0.95902   0.211717
# min    -0.631400  -2.890100  -2.830000  -0.234500  -2.26190  -0.208000
# 25%     0.262275  -1.120425  -0.627250  -0.100525  -0.07850   0.124275
# 50%     0.423200  -0.460900  -0.291300   0.004450   0.37475   0.234500
# 75%     0.618650   0.234500  -0.144725   0.345600   0.44675   0.247175
# max     2.345800   0.567800   1.109900   1.965800   0.80340   0.524900
#
#            Amount      Class
# count   10.000000  10.000000
# mean    87.545000   0.200000
# std    115.294577   0.421637
# min      0.000000   0.000000
# 25%      5.767500   0.000000
# 50%     57.495000   0.000000
# 75%    115.122500   0.000000
# max    378.660000   1.000000
#
# [8 rows x 23 columns]

# %%
print(df["Class"].value_counts())
# Out:
# Class
# 0    8
# 1    2
# Name: count, dtype: int64

# %%
sns.countplot(x="Class", data=df)
plt.title("Fraud vs Normal Transactions")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["Amount"], bins=50)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Class", y="Amount", data=df)
plt.title("Fraud vs Normal Transaction Amount")
plt.show()
