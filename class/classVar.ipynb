# %%
class student:
	college = "mits"
	def __init__(self, name, roll):
		self.name = name
		self.roll = roll
	@classmethod
	def set_college(cls, college):
		cls.college = college

	@staticmethod
	def info():
		print("this is a student class")

# %%
s1 = student()
s2 = student()
print(s1.college)
print(s2.college)
# Out:
# mits
# mits

# %%
#student.college = "manipal"
s1.college = "manipal"
print(s1.college)
print(s2.college)
print(student.college)
# Out:
# manipal
# mits
# mits
